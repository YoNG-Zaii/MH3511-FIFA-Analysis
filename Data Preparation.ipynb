# %% [markdown]
# ### Dataset
#
# Players:
#
# https://www.kaggle.com/datasets/sanjeetsinghnaik/fifa-23-players-dataset
#
# `/fifa23_players_data.csv`
#
# Teams:
#
# Partial: https://www.kaggle.com/datasets/cashncarry/fifa-23-complete-player-dataset?select=teams_fifa23.csv
#
# `./fifa23_teams_data.csv`
#
# Full: https://www.kaggle.com/datasets/stefanoleone992/fifa-23-complete-player-dataset?select=male_teams.csv
#
# File too large to commit

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#
# File ~\AppData\Roaming\Python\Python38\site-packages\pandas\__init__.py:16
#      13         missing_dependencies.append(f"{dependency}: {e}")
#      15 if missing_dependencies:
# ---> 16     raise ImportError(
#      17         "Unable to import required dependencies:\n" + "\n".join(missing_dependencies)
#      18     )
#      19 del hard_dependencies, dependency, missing_dependencies
#      21 # numpy compat
#
# ImportError: Unable to import required dependencies:
# numpy: No module named 'numpy'
# pytz: No module named 'pytz'

# %%
players = pd.read_csv("./fifa23_players_data.csv")
players.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %%
players.columns
# Out:
# Index(['Known As', 'Full Name', 'Overall', 'Potential', 'Value(in Euro)',
#        'Positions Played', 'Best Position', 'Nationality', 'Image Link', 'Age',
#        'Height(in cm)', 'Weight(in kg)', 'TotalStats', 'BaseStats',
#        'Club Name', 'Wage(in Euro)', 'Release Clause', 'Club Position',
#        'Contract Until', 'Club Jersey Number', 'Joined On', 'On Loan',
#        'Preferred Foot', 'Weak Foot Rating', 'Skill Moves',
#        'International Reputation', 'National Team Name',
#        'National Team Image Link', 'National Team Position',
#        'National Team Jersey Number', 'Attacking Work Rate',
#        'Defensive Work Rate', 'Pace Total', 'Shooting Total', 'Passing Total',
#        'Dribbling Total', 'Defending Total', 'Physicality Total', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys',
#        'Dribbling', 'Curve', 'Freekick Accuracy', 'LongPassing', 'BallControl',
# ...

# %%
teams = pd.read_csv("./fifa23_teams_data.csv")
# filter to latest version
# teams = teams[teams["fifa_update_date"] == "2023-01-13"]
teams.head()
# Out:
#        ID             Name                      League  LeagueId  Overall  \
# 0    1943  AFC Bournemouth  English Premier League (1)        13       74
# 1  116418     AFC Richmond  English Premier League (1)        13       78
# 2       1          Arsenal  English Premier League (1)        13       80
# 3       2      Aston Villa  English Premier League (1)        13       79
# 4    1925        Brentford  English Premier League (1)        13       75
#
#    Attack  Midfield  Defence  TransferBudget  DomesticPrestige  IntPrestige  \
# 0      75        73       73               0                 2            1
# 1      81        79       77               0                 5            3
# 2      83        81       79               0                 7            7
# 3      79        78       80               0                 5            3
# 4      75        74       75               0                 1            1
#
#    Players  StartingAverageAge  AllTeamAverageAge
# ...

# %% [markdown]
# **Big 5 Leagues**
# 1. Premier League in England
# 2. Bundesliga in Germany
# 3. La Liga in Spain
# 4. Serie A in Italy
# 5. Ligue 1 in France

# %%
team_only = teams[["Name"]]
team_only.head()
# Out:
#               Name
# 0  AFC Bournemouth
# 1     AFC Richmond
# 2          Arsenal
# 3      Aston Villa
# 4        Brentford

# %%
combined = pd.merge(players, team_only, left_on=["Club Name"], right_on=["Name"], how='left')
combined.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  CM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         88
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         84
# ...
